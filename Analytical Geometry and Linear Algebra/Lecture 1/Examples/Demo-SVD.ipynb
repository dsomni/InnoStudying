# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# import picture
pic = Image.open('images-2.jpeg')

pic = pic.convert('L')
# let's have a look
plt.imshow(pic,cmap='gray')
plt.show()
pic = np.array(pic)

# %%
# SVD (singular value decomposition)

U,S,V = np.linalg.svd( pic )

# plot the spectrum
plt.plot(S,'r-')
plt.xlim([-2,270])
plt.xlabel('Component number')
plt.ylabel('Singular value (\sigma)')
plt.show()
print(S[:15])
# Out:
# [20170.43499544  5730.13009607  4570.59977776  2851.04982047
#   2218.47201831  1938.07507502  1715.21886901  1451.6973425
#   1386.12655984  1310.05522006  1202.0898039   1051.05200944
#   1041.19087449   949.64564227   901.98050115]

# %%
# reconstruct the image based on some components

# list the components you want to use for the reconstruction
comps = np.arange(0,15)

# reconstruct the low-rank version of the picture
reconPic = U[:,comps]@np.diag(S[comps])@V[comps,:]


# show the original and reconstructed pictures for comparison
plt.figure(figsize=(10,20))
plt.subplot(1,2,1)
plt.imshow(pic,cmap='gray')
plt.title('Original')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(reconPic,cmap='gray')
plt.title('Components %s-%s' %(comps[0],comps[-1]))
plt.axis('off')

plt.show()

# %%
# reconstruct the image based on some components

# list the components you want to use for the reconstruction
comps = np.arange(15,120)

# reconstruct the low-rank version of the picture
reconPic = U[:,comps]@np.diag(S[comps])@V[comps,:]


# show the original and reconstructed pictures for comparison
plt.figure(figsize=(10,20))
plt.subplot(1,2,1)
plt.imshow(pic,cmap='gray')
plt.title('Original')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(reconPic,cmap='gray')
plt.title('Components %s-%s' %(comps[0],comps[-1]))
plt.axis('off')

plt.show()
